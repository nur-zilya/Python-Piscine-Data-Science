# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import sqlite3

# %%
data = sqlite3.connect('/content/drive/My Drive/data/checking-logs.sqlite.sqlite')

# %%
schema = pd.io.sql.read_sql("PRAGMA table_info(checker);", data)
schema
# Out:
#    cid       name       type  notnull dflt_value  pk
# 0    0      index    INTEGER        0       None   0
# 1    1     status       TEXT        0       None   0
# 2    2    success    INTEGER        0       None   0
# 3    3  timestamp  TIMESTAMP        0       None   0
# 4    4  numTrials    INTEGER        0       None   0
# 5    5    labname       TEXT        0       None   0
# 6    6        uid       TEXT        0       None   0

# %%
cur = data.cursor()
cur.execute('select * from checker')
cur.fetchmany(10)
# Out:
# [(0, 'checking', 0, '2020-04-16 21:12:50.740474', 5, None, 'admin_1'),
#  (1, 'ready', 0, '2020-04-16 21:12:54.708365', 5, 'code_rvw', 'admin_1'),
#  (2, 'checking', 0, '2020-04-16 21:46:47.769088', 7, None, 'admin_1'),
#  (3, 'ready', 0, '2020-04-16 21:46:48.121217', 7, 'lab02', 'admin_1'),
#  (4, 'checking', 0, '2020-04-16 21:53:01.862637', 6, 'code_rvw', 'admin_1'),
#  (5, 'ready', 0, '2020-04-16 21:53:05.373389', 6, 'code_rvw', 'admin_1'),
#  (6, 'checking', 0, '2020-04-17 05:18:51.965864', 1, None, None),
#  (7, 'ready', 0, '2020-04-17 05:19:02.744528', 1, 'project1', 'user_4'),
#  (8, 'checking', 0, '2020-04-17 05:22:35.249331', 2, 'project1', 'user_4'),
#  (9, 'ready', 1, '2020-04-17 05:22:45.549397', 2, 'project1', 'user_4')]

# %%
query = 'SELECT * FROM checker LIMIT 10'
pd.io.sql.read_sql(query, data)
# Out:
#    index    status  success                   timestamp  numTrials   labname  \
# 0      0  checking        0  2020-04-16 21:12:50.740474          5      None
# 1      1     ready        0  2020-04-16 21:12:54.708365          5  code_rvw
# 2      2  checking        0  2020-04-16 21:46:47.769088          7      None
# 3      3     ready        0  2020-04-16 21:46:48.121217          7     lab02
# 4      4  checking        0  2020-04-16 21:53:01.862637          6  code_rvw
# 5      5     ready        0  2020-04-16 21:53:05.373389          6  code_rvw
# 6      6  checking        0  2020-04-17 05:18:51.965864          1      None
# 7      7     ready        0  2020-04-17 05:19:02.744528          1  project1
# 8      8  checking        0  2020-04-17 05:22:35.249331          2  project1
# 9      9     ready        1  2020-04-17 05:22:45.549397          2  project1
#
#        uid
# 0  admin_1
# 1  admin_1
# 2  admin_1
# 3  admin_1
# 4  admin_1
# 5  admin_1
# 6     None
# 7   user_4
# ...

# %%
query = "SELECT COUNT(*) as cnt FROM (SELECT uid FROM pageviews WHERE uid IN \
(SELECT uid FROM checker WHERE status='ready' AND numtrials=1 AND labname IN ('laba04', 'laba04s', 'laba05', 'laba06', 'laba06s', 'project1')))"
pd.io.sql.read_sql(query, data)
# Out:
#    cnt
# 0  985

# %%
cur.close()
data.close()
